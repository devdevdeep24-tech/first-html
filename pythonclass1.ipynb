# %% [markdown]
# <a href="https://colab.research.google.com/github/devdevdeep24-tech/first-html/blob/main/pythonclass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Dev"
age = "25"
print(name)
print(age)
# Out:
# Dev
# 25

# %%
l = 20
b = 30
sum = (l + b) // 2
print(sum)
# Out:
# 25

# %%
firstname="Dev"
Middlename="Deep"
Lastname="Mishra"
print(firstname)
print(Middlename)
print(Lastname)
print(firstname,Middlename,Lastname)
# Out:
# Dev
# Deep
# Mishra
# Dev Deep Mishra

# %%
rosecolor=input("what is the color?")
print("color is",rosecolor)
if rosecolor=="red":
    print("rose is red")
else:
    print("rose is not red")
# Out:
# what is the color?yellow
# color is yellow
# rose is not red

# %%
n=int(input("how many roses?"))
print("the roses are: ",n)
# Out:
# how many roses?45
# the roses are:  45

# %%
a=int(input("how many roses?"))
b=int(input("enter number"))
sum=a+b
print("the roses are:",sum)
# Out:
# how many roses?8
# enter number8
# the roses are: 16

# %%
p=float(input("Enter price:"))
print("price of the product is:",p)
# Out:
# Enter price:52.5
# price of the product is: 52.5

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
place=input("enter your place:")
print("My name is",name,"and my age is",age,"and i am from",place,".")
# Out:
# enter your name:dev
# enter your age:22
# enter your place:ghz
# My name is dev and my age is 22 and i am from ghz .

# %%
var1=22
var2="ddm"
var3=44.5
print(var1,var2,var3)
# Out:
# 22 ddm 44.5

# %%
l=10
b=20
area=l*b
print("area of the rectangle is:",area)
# Out:
# area of the rectangle is: 200

# %%
a=2
b=0.2
c="svdfjhgsdjfhsk"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
x=4+3j
print(x)
print(type(x))
# Out:
# (4+3j)
# <class 'complex'>

# %%
a=complex(2,5)
print(a)
print(type(a))
# Out:
# (2+5j)
# <class 'complex'>
